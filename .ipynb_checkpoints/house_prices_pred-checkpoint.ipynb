# %%
import pandas as pd
import numpy as np

from matplotlib import pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ##### Reading and Understanding the Data

# %%
data = pd.DataFrame(pd.read_csv('melb_data.csv'))
pd.options.display.float_format = '{:.4f}'.format

# %%
data.head()
# Out:
#        Suburb           Address  Rooms Type        Price Method SellerG  \
# 0  Abbotsford      85 Turner St      2    h 1480000.0000      S  Biggin
# 1  Abbotsford   25 Bloomburg St      2    h 1035000.0000      S  Biggin
# 2  Abbotsford      5 Charles St      3    h 1465000.0000     SP  Biggin
# 3  Abbotsford  40 Federation La      3    h  850000.0000     PI  Biggin
# 4  Abbotsford       55a Park St      4    h 1600000.0000     VB  Nelson
#
#         Date  Distance  Postcode  ...  Bathroom    Car  Landsize  \
# 0  3/12/2016    2.5000 3067.0000  ...    1.0000 1.0000  202.0000
# 1  4/02/2016    2.5000 3067.0000  ...    1.0000 0.0000  156.0000
# 2  4/03/2017    2.5000 3067.0000  ...    2.0000 0.0000  134.0000
# 3  4/03/2017    2.5000 3067.0000  ...    2.0000 1.0000   94.0000
# 4  4/06/2016    2.5000 3067.0000  ...    1.0000 2.0000  120.0000
#
#    BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude  \
# 0           NaN        NaN        Yarra  -37.7996    144.9984
# ...

# %%
data.shape
# Out:
# (13580, 21)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13580 entries, 0 to 13579
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Suburb         13580 non-null  object
#  1   Address        13580 non-null  object
#  2   Rooms          13580 non-null  int64
#  3   Type           13580 non-null  object
#  4   Price          13580 non-null  float64
#  5   Method         13580 non-null  object
#  6   SellerG        13580 non-null  object
#  7   Date           13580 non-null  object
#  8   Distance       13580 non-null  float64
#  9   Postcode       13580 non-null  float64
#  10  Bedroom2       13580 non-null  float64
#  11  Bathroom       13580 non-null  float64
#  12  Car            13518 non-null  float64
#  13  Landsize       13580 non-null  float64
#  14  BuildingArea   7130 non-null   float64
#  15  YearBuilt      8205 non-null   float64
#  16  CouncilArea    12211 non-null  object
# ...

# %%
data.describe().T
# Out:
#                    count         mean         std        min         25%  \
# Rooms         13580.0000       2.9380      0.9557     1.0000      2.0000
# Price         13580.0000 1075684.0795 639310.7243 85000.0000 650000.0000
# Distance      13580.0000      10.1378      5.8687     0.0000      6.1000
# Postcode      13580.0000    3105.3019     90.6770  3000.0000   3044.0000
# Bedroom2      13580.0000       2.9147      0.9659     0.0000      2.0000
# Bathroom      13580.0000       1.5342      0.6917     0.0000      1.0000
# Car           13518.0000       1.6101      0.9626     0.0000      1.0000
# Landsize      13580.0000     558.4161   3990.6692     0.0000    177.0000
# BuildingArea   7130.0000     151.9676    541.0145     0.0000     93.0000
# YearBuilt      8205.0000    1964.6842     37.2738  1196.0000   1940.0000
# Lattitude     13580.0000     -37.8092      0.0793   -38.1825    -37.8568
# Longtitude    13580.0000     144.9952      0.1039   144.4318    144.9296
# ...

# %%
data.describe(include=np.object).T
# Out:
#              count unique                    top  freq
# Suburb       13580    314              Reservoir   359
# Address      13580  13378       36 Aberfeldie St     3
# Type         13580      3                      h  9449
# Method       13580      5                      S  9022
# SellerG      13580    268                 Nelson  1565
# Date         13580     58             27/05/2017   473
# CouncilArea  12211     33               Moreland  1163
# Regionname   13580      8  Southern Metropolitan  4695

# %%
print("Types:", data['Type'].unique())
print("Methods:", data['Method'].unique())
print("Regions:", data['Regionname'].unique())
# Out:
# Types: ['h' 'u' 't']
# Methods: ['S' 'SP' 'PI' 'VB' 'SA']
# Regions: ['Northern Metropolitan' 'Western Metropolitan' 'Southern Metropolitan'
#  'Eastern Metropolitan' 'South-Eastern Metropolitan' 'Eastern Victoria'
#  'Northern Victoria' 'Western Victoria']

# %% [markdown]
# ##### Data Cleaning

# %%
# checking missing values

data.isnull().sum()*100/data.shape[0]
# Out:
# Suburb           0.0000
# Address          0.0000
# Rooms            0.0000
# Type             0.0000
# Price            0.0000
# Method           0.0000
# SellerG          0.0000
# Date             0.0000
# Distance         0.0000
# Postcode         0.0000
# Bedroom2         0.0000
# Bathroom         0.0000
# Car              0.4566
# Landsize         0.0000
# BuildingArea    47.4963
# YearBuilt       39.5803
# CouncilArea     10.0810
# Lattitude        0.0000
# Longtitude       0.0000
# Regionname       0.0000
# Propertycount    0.0000
# dtype: float64

# %%
data.loc[:,'Car'].head()
# Out:
# 0   1.0000
# 1   0.0000
# 2   0.0000
# 3   1.0000
# 4   2.0000
# Name: Car, dtype: float64

# %% [markdown]
# ##### Replace Missing Values with Zero in Cars Column and YearBuilt with value that comes directly after it

# %%
data['Car'].fillna(value=0, inplace=True)
data['YearBuilt'].fillna(method='bfill', axis=0, inplace=True)

# %% [markdown]
# ##### Drop BuildingArea and CouncilArea

# %%
data.dropna(axis=1, inplace=True)

# %%
data.isnull().sum()*100/data.shape[0]
# Out:
# Suburb          0.0000
# Address         0.0000
# Rooms           0.0000
# Type            0.0000
# Price           0.0000
# Method          0.0000
# SellerG         0.0000
# Date            0.0000
# Distance        0.0000
# Postcode        0.0000
# Bedroom2        0.0000
# Bathroom        0.0000
# Car             0.0000
# Landsize        0.0000
# YearBuilt       0.0000
# Lattitude       0.0000
# Longtitude      0.0000
# Regionname      0.0000
# Propertycount   0.0000
# dtype: float64

# %%
data.describe().T
# Out:
#                    count         mean         std        min         25%  \
# Rooms         13580.0000       2.9380      0.9557     1.0000      2.0000
# Price         13580.0000 1075684.0795 639310.7243 85000.0000 650000.0000
# Distance      13580.0000      10.1378      5.8687     0.0000      6.1000
# Postcode      13580.0000    3105.3019     90.6770  3000.0000   3044.0000
# Bedroom2      13580.0000       2.9147      0.9659     0.0000      2.0000
# Bathroom      13580.0000       1.5342      0.6917     0.0000      1.0000
# Car           13580.0000       1.6027      0.9665     0.0000      1.0000
# Landsize      13580.0000     558.4161   3990.6692     0.0000    177.0000
# YearBuilt     13580.0000    1964.8023     36.5335  1196.0000   1941.0000
# Lattitude     13580.0000     -37.8092      0.0793   -38.1825    -37.8568
# Longtitude    13580.0000     144.9952      0.1039   144.4318    144.9296
# Propertycount 13580.0000    7454.4174   4378.5818   249.0000   4380.0000
#
# ...

# %% [markdown]
# ##### Outlier Analysis

# %%
fig, axs = plt.subplots(3,3, figsize = (10,5))

plt1 = sns.boxplot(data['Price'], ax=axs[0,0])
plt2 = sns.boxplot(data['Rooms'], ax = axs[0,1])
plt3 = sns.boxplot(data['Distance'], ax = axs[0,2])
plt11 = sns.boxplot(data['Postcode'], ax = axs[1,0])
plt22 = sns.boxplot(data['Bedroom2'], ax = axs[1,1])
plt33 = sns.boxplot(data['Bathroom'], ax = axs[1,2])
plt111 = sns.boxplot(data['Car'], ax = axs[2,0])
plt222 = sns.boxplot(data['Landsize'], ax = axs[2,1])
plt333 = sns.boxplot(data['YearBuilt'], ax = axs[2,2])

plt.tight_layout()

# %%
plt.boxplot(data.Price)

Q1 = data.Price.quantile(0.25)
Q3 = data.Price.quantile(0.75)

IQR = Q3 - Q1
data = data[(data.Price >= Q1 - 1.5*IQR) & (data.Price <= Q3 + 1.5*IQR)]
